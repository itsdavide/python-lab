# %%
# Import the libraries
import pandas as pd

# %%
amzn = pd.read_csv('AMZN.csv')
amzn
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-04-24  107.660004  109.230003  105.070000  106.209999  106.209999
# 1    2023-04-25  104.910004  105.449997  102.449997  102.570000  102.570000
# 2    2023-04-26  105.040001  106.620003  104.099998  104.980003  104.980003
# 3    2023-04-27  108.160004  110.860001  106.800003  109.820000  109.820000
# 4    2023-04-28  107.730003  109.480003  104.330002  105.449997  105.449997
# ..          ...         ...         ...         ...         ...         ...
# 247  2024-04-17  184.309998  184.570007  179.820007  181.279999  181.279999
# 248  2024-04-18  181.470001  182.389999  178.649994  179.220001  179.220001
# 249  2024-04-19  178.740005  179.000000  173.440002  174.630005  174.630005
# 250  2024-04-22  176.940002  178.869995  174.559998  177.229996  177.229996
# 251  2024-04-23  178.080002  179.929993  175.979996  179.539993  179.539993
#
#         Volume
# 0     69575600
# 1     65026800
# 2     73803800
# 3    149961200
# 4    130565000
# ..         ...
# 247   31359700
# 248   30723800
# 249   55950000
# 250   37924900
# 251   35814300
#
# [252 rows x 7 columns]

# %%
amzn.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   143.560437  145.141190  142.050913  143.654881  143.654881
# std     21.484075   21.493163   21.395711   21.493440   21.493440
# min    101.470001  103.900002  101.150002  102.050003  102.050003
# 25%    128.735004  130.194996  127.220001  128.389996  128.389996
# 50%    139.265007  140.659996  137.620002  139.085007  139.085007
# 75%    156.124996  157.504997  154.144997  155.509998  155.509998
# max    187.720001  189.770004  185.509995  189.050003  189.050003
#
#              Volume
# count  2.520000e+02
# mean   5.188759e+07
# std    1.946285e+07
# min    2.237840e+07
# 25%    4.090148e+07
# 50%    4.806350e+07
# 75%    5.694408e+07
# max    1.529387e+08

# %%
# Create a DataFrame for TSLA
tsla = pd.read_csv('TSLA.csv')
tsla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-04-24  164.649994  165.649994  158.610001  162.550003  162.550003
# 1    2023-04-25  159.820007  163.470001  158.750000  160.669998  160.669998
# 2    2023-04-26  160.289993  160.669998  153.139999  153.750000  153.750000
# 3    2023-04-27  152.639999  160.479996  152.369995  160.190002  160.190002
# 4    2023-04-28  160.899994  165.000000  157.320007  164.309998  164.309998
# ..          ...         ...         ...         ...         ...         ...
# 247  2024-04-17  157.639999  158.330002  153.779999  155.449997  155.449997
# 248  2024-04-18  151.250000  152.199997  148.699997  149.929993  149.929993
# 249  2024-04-19  148.970001  150.940002  146.220001  147.050003  147.050003
# 250  2024-04-22  140.559998  144.440002  138.800003  142.050003  142.050003
# 251  2024-04-23  143.330002  147.259995  141.110001  144.679993  144.679993
#
#         Volume
# 0    140006600
# 1    121999300
# 2    153364100
# 3    127015200
# 4    122515800
# ..         ...
# 247   82439700
# 248   96098800
# 249   86005100
# 250  107097600
# 251  106808100
#
# [252 rows x 7 columns]

# %%
tsla.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   220.868810  225.029246  216.652738  220.958651  220.958651
# std     37.432201   37.940826   36.809090   37.378912   37.378912
# min    140.559998  144.440002  138.800003  142.050003  142.050003
# 25%    185.450001  189.212505  182.107502  186.909996  186.909996
# 50%    229.955002  235.364998  225.959999  232.120003  232.120003
# 75%    251.562496  257.977501  247.324993  252.699993  252.699993
# max    296.040009  299.290009  289.519989  293.339996  293.339996
#
#              Volume
# count  2.520000e+02
# mean   1.174262e+08
# std    2.538041e+07
# min    6.450660e+07
# 25%    1.015020e+08
# 50%    1.127194e+08
# 75%    1.313453e+08
# max    2.117971e+08

# %%
# Create a joint DataFrame of equity prices
amzn = amzn[['Date', 'Close']].set_index('Date')
tsla = tsla[['Date', 'Close']].set_index('Date')

joint_equity = pd.merge(amzn, tsla,
                       left_index=True,
                       right_index=True)

joint_equity
# Out:
#                Close_x     Close_y
# Date
# 2023-04-24  106.209999  162.550003
# 2023-04-25  102.570000  160.669998
# 2023-04-26  104.980003  153.750000
# 2023-04-27  109.820000  160.190002
# 2023-04-28  105.449997  164.309998
# ...                ...         ...
# 2024-04-17  181.279999  155.449997
# 2024-04-18  179.220001  149.929993
# 2024-04-19  174.630005  147.050003
# 2024-04-22  177.229996  142.050003
# 2024-04-23  179.539993  144.679993
#
# [252 rows x 2 columns]

# %%
joint_equity.columns = ['amzn', 'tsla']
joint_equity
# Out:
#                   amzn        tsla
# Date
# 2023-04-24  106.209999  162.550003
# 2023-04-25  102.570000  160.669998
# 2023-04-26  104.980003  153.750000
# 2023-04-27  109.820000  160.190002
# 2023-04-28  105.449997  164.309998
# ...                ...         ...
# 2024-04-17  181.279999  155.449997
# 2024-04-18  179.220001  149.929993
# 2024-04-19  174.630005  147.050003
# 2024-04-22  177.229996  142.050003
# 2024-04-23  179.539993  144.679993
#
# [252 rows x 2 columns]

# %%
# Save the joint DataFrame as CSV
joint_equity.to_csv('joint_equity.csv')

# %%
# Show the histograms
joint_equity.hist()
# Out:
# array([[<Axes: title={'center': 'amzn'}>,
#         <Axes: title={'center': 'tsla'}>]], dtype=object)

# %%
# Show the plots
joint_equity.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Show the correlation matrix
joint_equity.corr()
# Out:
#           amzn      tsla
# amzn  1.000000 -0.356018
# tsla -0.356018  1.000000

# %%
# Compute the linear regression
from scipy import stats

linear_regression = stats.linregress(
    x = joint_equity['amzn'], 
    y = joint_equity['tsla'])

a = linear_regression.slope
b = linear_regression.intercept

# %%
# Linear prediction of a price
x = 300 # AMZN price
y = a*x + b
y
# Out:
# 124.15840364158487

# %%
# Plot the regression line using Seaborn library
import seaborn as sn

axes = sn.regplot(x = joint_equity['amzn'], 
    y = joint_equity['tsla'])

# %%
# We repeat the linear regression for the crypto securities
btc = pd.read_csv('BTC-USD.csv')
eth = pd.read_csv('ETH-USD.csv')

# Create a joint DataFrame of crypto prices
btc = btc[['Date', 'Close']].set_index('Date')
eth = eth[['Date', 'Close']].set_index('Date')

joint_crypto = pd.merge(btc, eth,
                       left_index=True,
                       right_index=True)

joint_crypto.columns = ['btc', 'eth']

# Plot the regression line using Seaborn library
axes = sn.regplot(x = joint_crypto['btc'], 
    y = joint_crypto['eth'])
